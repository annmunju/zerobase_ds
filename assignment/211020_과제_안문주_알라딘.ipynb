# %%
# requirements 

import pandas as pd 
from urllib.request import urlopen 
from bs4 import BeautifulSoup

# %% [markdown]
# # 문제1) 출판 도서 정보 수집
#
# 알라딘 사이트 내에 있는 도서 정보를 바탕으로 책 내용을 분석할 예정입니다.
# 알라딘은 프로그래밍 언어별로 카테고리를 나누어 찾기 용이하게 되어있습니다.
# 각 카테고리 별 주소는 다음과 같습니다.
# - 파이썬 : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=6734
# - C언어 : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=6385
# - 자바  : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=2502
# - C++  : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=6386
# - C#   : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=6360
# - Visual Basic : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=6353
# - JavaScript : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=7397
# - SQL  : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=6593
# - PHP  : https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=6351
# - R : https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&KeyTitle=R&KeyRecentPublish=0&CategorySearch=%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D+%EC%96%B8%EC%96%B4%40437&OutStock=0&ViewType=Detail&SortOrder=11&CustReviewCount=0&CustReviewRank=0&KeyFullWord=R&KeyLastWord=R&SearchFieldEnable=1&KeyWord=&chkKeyTitle=on&chkKeyAuthor=&chkKeyPublisher=&chkKeyISBN=&chkKeyTag=&chkKeyTOC=&chkKeySubject=&ViewRowCount=50
#     - R은 다른 도서와 다르게 카테고리 분류가 되어있지 않아 컴퓨터 > 프로그래밍 언어 > R이 제목에 있는 도서만을 검색함. 또한 한페이지에 모든 정보가 기록되지 않음.

# %%
url = "https://www.aladin.co.kr/shop/wbrowse.aspx?BrowseTarget=List&SortOrder=2&ViewType=Detail&ViewRowsCount=1000&PublishMonth=0&PublishDay=84&UsedShop=0&DiscountPercent=20&BranchType=1&Stockstatus=1&CID=6734"
response = urlopen(url)
# response.status 
soup = BeautifulSoup(response, "html.parser")
#print(soup.prettify())
soup.find_all("ul")
exchangeList = soup.select(".ss_book_list > ul")
len(exchangeList), exchangeList
# Out:
# (1477,
#  [<ul>
#   <li><span class="ss_ht1">[<a href="/events/wevent_redirect.aspx?eventid=222576">한빛미디어 도서 구매시, 혼공 AI 티글라스!</a>]</span><br/></li><li><a class="bo3" href="https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=193931483"><b>혼자 공부하는 파이썬</b></a><span class="ss_f_g2"> - 파이썬 최신 버전 반영</span> <span style="color: #777777">ㅣ</span> <a class="ss_f_g2" href="http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=674661">혼자 공부하는 시리즈 </a> </li>
# ...
